# %%
import numpy as np
import matplotlib.pyplot as plt

def idft(X):
    N = len(X)
    x = np.zeros(N, dtype=complex)
    
    for n in range(N):
        for k in range(N):
            x[n] += X[k] * np.exp(1j * 2 * np.pi * k * n / N)
    
    return x / N

X = [7, 2, 4, 3, 4, 5, 0, 0, 0, 0]
x = idft(X) 
print("Time domain signal:", x)

# Plotting
plt.figure(figsize=(12, 6))

# Plot real part
plt.subplot(1, 2, 1)
plt.stem(np.real(x), use_line_collection=True)
plt.title("Real Part of IDFT")
plt.xlabel("Sample index")
plt.ylabel("Amplitude")

# Plot imaginary part
plt.subplot(1, 2, 2)
plt.stem(np.imag(x), use_line_collection=True)
plt.title("Imaginary Part of IDFT")
plt.xlabel("Sample index")
plt.ylabel("Amplitude")

plt.tight_layout()
plt.show()
# Out:
# Time domain signal: [2.5      +0.00000000e+00j 0.0690983+1.01841071e+00j
#  0.8190983-1.31432778e-01j 0.1809017+1.59184233e-01j
#  0.9309017-2.12662702e-01j 0.5      +1.46957616e-16j
#  0.9309017+2.12662702e-01j 0.1809017-1.59184233e-01j
#  0.8190983+1.31432778e-01j 0.0690983-1.01841071e+00j]
